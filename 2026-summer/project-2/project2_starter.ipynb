# %% [markdown]
# # Project 2: Predicting Credit Default — starter notebook
#
# **ACCTG 5150-090 · Due Wednesday, July 15, 12:00 noon MT**
#
# First: `File → Save a copy in Drive`, and work in your copy.
#
# The full project guide (scenario, deliverables, rubric, workflow): [Project 2 guide](https://seanmccaman.com/acctg5150/2026-summer/project-2/project_2_guide.html)
#
# Before you submit: run every cell top to bottom (`Runtime → Run all`) so the outputs are saved, then `File → Download → Download .ipynb`.

# %% [markdown]
# ## Step 1 — Load and inspect
#
# The load cell is written for you. Get to know the data: what is one row, what is the overall default rate, how does it vary across a couple of features?

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/sean-mccaman/acctg5150-090/main/2026-summer/project-2/ar_default_data.csv"
df = pd.read_csv(url)
df.head()

# %%
# Your exploration here. A good first look:
# df.describe(), df["bad_ar"].mean(), df.groupby("pay_this_month")["bad_ar"].mean()

# %% [markdown]
# ## Step 2 — Fit the model
#
# Logistic regression predicting `bad_ar` from the six Feature columns (leave the demographic columns out unless your Challenge & Verify log makes the case). Have the AI write the fit, or write it yourself — then read the output: which features matter, and does the direction of each make business sense?

# %%
# Fit the logistic regression model here.

# %% [markdown]
# ## Step 3 — Evaluate at a starting cutoff
#
# Start at 0.5. Build the confusion matrix, then precision and recall. (Week 9 teaches these.)

# %%
# Confusion matrix, precision, recall at cutoff = 0.5

# %% [markdown]
# ## Step 4 — Sweep the cutoff
#
# Try a range of cutoffs and watch precision and recall trade off.

# %%
# Cutoff sweep here.

# %% [markdown]
# ## Step 5 — The cost decision (the heart of the project)
#
# State your two costs in dollars (a missed default, a wrongly flagged good customer). For each candidate cutoff: total expected cost = (defaults missed × cost of a miss) + (good customers flagged × cost of a false alarm). Recommend the cutoff with the lowest total.

# %%
# Expected-cost table by cutoff, and your recommended cutoff.

# %% [markdown]
# ## Step 6 — Challenge & Verify log
#
# Run at least two prompts against your own work (see the guide, Section 4.3). Fill in one block per prompt below, in your own words. Remember: you also paste the prompt text itself into the submission form on Canvas.
#
# ---
#
# ### Prompt 1
# - **The prompt:**
# - **What it flagged:**
# - **Did it change your work?**
# - **Did you check it?**
#
# ### Prompt 2
# - **The prompt:**
# - **What it flagged:**
# - **Did it change your work?**
# - **Did you check it?**
#
# ### (Optional) Prompt 3
# - **The prompt:**
# - **What it flagged:**
# - **Did it change your work?**
# - **Did you check it?**
#
# **Closing line — the single most useful thing a prompt surfaced, and how you decided whether to trust it:**
